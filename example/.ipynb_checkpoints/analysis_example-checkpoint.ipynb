# %% [markdown]
# # Example of how to analyze the R and H-alpha images for a particular galaxy

# %%
import numpy as np
from matplotlib import pyplot as plt
from astropy.io import fits
# %matplotlib inline

# %% [markdown]
# ## Create mask
#
# PROGRAMS:
#
# * uat_mask.py = makes mask for one images
# * uat_mask_all.py = runs uat_mask.py on images that match a given prefix

# %%
# %run ~/github/HalphaImaging/uat_mask.py --help
# Out:
# usage: uat_mask.py [-h] [--image IMAGE] [--d D] [--threshold THRESHOLD]
#
# Create a mask for extraneous objects in field
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --image IMAGE         image to mask
#   --d D                 Locates path of default config files
#   --threshold THRESHOLD
#                         sextractor DEBLEND_MINCONT: 0=lots of deblending;
#                         1=none (default = .005)

# %%
# %run ~/github/HalphaImaging/uat_mask.py --image A1367-140231-R.fits
# Out:
# enter:
#    pixel value to remove object in mask;
#    t to adjust SE threshold (0=no deblend, 1=lots);
#    w to write output and quit;
#    q to quit without saving
# w

# %% [markdown]
# ## Subtract Continuum
#
# PROGRAM: uat_subtract_continuum.py
#
# STATUS:  complete
#
# HOW TO USE:
# * from within ipython -pylab
#     * %run ~/github/HalphaImaging/uat_subtract_continuum.py --r A1367-h02_R.coadd.fits --ha A1367-h02_ha12.coadd.fits --scale .055
# * you can then adjust the scale value, where the continuum-subtracted image is
#     * $ continuum\_subtracted = H\alpha - scale \times R$
# * you can run this on individual cutouts or on the entire mosaic
# * you can feed in the R and H$\alpha$ image names, or give the cluster prefix and NSAID as shown in the second example below.

# %%
# %run ~/github/HalphaImaging/uat_subtract_continuum.py --r A1367-140222-R.fits --ha A1367-140222-Ha.fits
# Out:
# enter new value for scale factor;
#    w to write output and quit;
#    q to quit without saving
# w

# %%
# %run ~/github/HalphaImaging/uat_subtract_continuum.py --cluster A1367 --id 140222
# Out:
# enter new value for scale factor;
#    w to write output and quit;
#    q to quit without saving
# w

# %% [markdown]
# ## Review Continuum-Subtracted Image
#
# * look at the continuum subtracted images to determine if the galaxy has H$\alpha$ emission.
# * the code looks for all images that are prefix\*-CS.fits

# %%
# %run ~/github/HalphaImaging/uat_review_contsub.py --cluster 'A1367'
# Out:
# prefix =  A1367-140222
# Does continuum-subtracted image show Halpha emission? (y or n, q to quit)
# y

# %% [markdown]
# ## Run Ellipse on R and CS Image
#
# * run in ipython -pylab
#
#    %run uat_runellipse.py --r r_image.fits --ha ha_image.fits
#
#
# * the H$\alpha$ image should be the continuum-subtracted H$\alpha$ image
# * this assumes that a mask file already exists
# * when running on coma, you need to run ur_setup first so that iraf is available.

# %%
# %run ~/github/HalphaImaging/uat_runellipse.py --cluster A1367 --id 140231
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Could not import aqutil, please see the online PyRAF FAQ
# http://www.stsci.edu/institute/software_hardware/pyraf/pyraf_faq#2.6
#
# Limited graphics available on OSX (aqutil not loaded)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit:
# Your "iraf" and "IRAFARCH" environment variables are not defined and could not
# be determined from /usr/local/bin/cl.  These are needed to find IRAF tasks.
# Before starting pyraf, define them by doing (for example):
#
#     setenv iraf /iraf/iraf/
#     setenv IRAFARCH linux
#
# at the Unix command line. Actual values will depend on your IRAF installation,
# and they are set during the IRAF user installation (see iraf.net), or via
# ...

# %% [markdown]
# ## Plot cutouts and Radial Profiles!

# %%
plt.close('all')
# %run ~/github/HalphaImaging/uat_cutouts_with_ellipse_profiles.py --r A1367-140231-R.fits --ha A1367-140231-Ha.fits
plt.show()
# Out:
# no convolved Halpha
# no convolved Halpha
# saving result as  A1367-140231-ellipse-profiles.png
