# %% [markdown]
# # Example of how to analyze the R and H-alpha images for a particular galaxy

# %%
import numpy as np
from matplotlib import pyplot as plt
from astropy.io import fits
# %matplotlib inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ## Create mask
#
# PROGRAM: uat_mask.py
#
# STATUS: under development

# %% [markdown]
# ## Subtract Continuum
#
# PROGRAM: uat_subtract_continuum.py
#
# STATUS:  complete
#
# HOW TO USE:
# * from within ipython -pylab
#     * %run ~/github/HalphaImaging/uat_subtract_continuum.py --r A1367-h02_R.coadd.fits --ha A1367-h02_ha12.coadd.fits --scale .055
# * you can then adjust the scale value, where the continuum-subtracted image is
#     * $ continuum\_subtracted = H\alpha - scale \times R$
# * you can run this on individual cutouts or on the entire mosaic

# %%
# %run ~/github/HalphaImaging/uat_subtract_continuum.py --r A1367-140222-R.fits --ha A1367-140222-Ha.fits
# Out:
# enter new value for scale factor;
#    w to write output and quit;
#    q to quit without saving
# .04
# enter new value for scale factor;
#    w to write output and quit;
#    q to quit without saving
# w

# %% [markdown]
# ## Run Ellipse on R and CS Image
#
# * run in ipython -pylab
#
#    %run uat_runellipse.py --r r_image.fits --ha ha_image.fits
#
#
# * this assumes that a mask file already exists
# * when running on coma, you need to run ur_setup first so that iraf is available.

# %%
# %run ~/github/HalphaImaging/uat_runellipse.py --r A1367-140231-R.fits --ha A1367-140231-Ha.fits
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/rfinn/github/HalphaImaging/uat_runellipse.py in <module>()
#      25 import os
#      26 from matplotlib import pyplot as plt
# ---> 27 from pyraf import iraf
#      28 from astropy.io import fits
#      29 import ds9
#
# //anaconda/lib/python2.7/site-packages/pyraf/__init__.py in <module>()
#      45
#      46 # Grab the terminal window's id at the earliest possible moment
# ---> 47 import wutil
#      48
#      49 # Since numpy as absolutely required for any PyRAF use, go ahead and
#
# //anaconda/lib/python2.7/site-packages/pyraf/wutil.py in <module>()
#      34 # "INIT_Processeses(), could not establish the default connection to the WindowServer.Abort".
#      35 # Give the user (Mac or other) a way to still run remotely with no display.
# ---> 36 from stsci.tools import capable
#      37 _skipDisplay = not capable.OF_GRAPHICS
#      38
#
# ImportError: No module named stsci.tools

# %% [markdown]
# ## Plot cutouts and Radial Profiles!

# %%
plt.close('all')
# %run ~/github/HalphaImaging/uat_cutouts_with_ellipse_profiles.py --r A1367-140231-R.fits --ha A1367-140231-Ha.fits
plt.show()
# Out:
# no convolved Halpha
# no convolved Halpha
# saving result as  A1367-140231-ellipse-profiles.png

# %%
from pyraf import iraf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-028579761c08> in <module>()
# ----> 1 from pyraf import iraf
#
# //anaconda/lib/python2.7/site-packages/pyraf/__init__.py in <module>()
#      45
#      46 # Grab the terminal window's id at the earliest possible moment
# ---> 47 import wutil
#      48
#      49 # Since numpy as absolutely required for any PyRAF use, go ahead and
#
# //anaconda/lib/python2.7/site-packages/pyraf/wutil.py in <module>()
#      34 # "INIT_Processeses(), could not establish the default connection to the WindowServer.Abort".
#      35 # Give the user (Mac or other) a way to still run remotely with no display.
# ---> 36 from stsci.tools import capable
#      37 _skipDisplay = not capable.OF_GRAPHICS
#      38
#
# ImportError: No module named stsci.tools

# %%
import stsci
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-ad7dd18f9e9a> in <module>()
# ----> 1 import stsci
#
# ImportError: No module named stsci
