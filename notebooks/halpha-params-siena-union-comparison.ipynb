# %% [markdown]
# # Comparing End Products #
#
# - I have run one field - NRGs27 - through the halpha gui
# - have measurements for size, magnitudes, morphologies
# - Can now compare to Becky's numbers and to NSA
#
# ## Program Details ##
#
# - The workhorse program is **compare_union.py** in ~/github/halphagui/testing
# - running from directory '/Users/rfinn/research/halphagui_test'

# %%
import os
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
working_dir = '/Users/rfinn/research/halphagui_test'
os.chdir(working_dir)

# %%
# %run ~/github/halphagui/testing/compare_union.py

# %% [markdown]
# ## Siena GALFIT vs NSA Sersic parameters ##

# %%
compare_sersic()

# %% [markdown]
# ## Siena vs  NSA SFR parameters  ##
#
# bottom left shows sfr vs NUV mag - this is the best correlation, not surprisingly; although the one outlier in NUV is throwing off the axis range.
#
# top left shows global SFR vs SDSS fiber HA flux - correlation ok

# %%
nsasfr()

# %% [markdown]
# ##  Siena vs NSA morphology measurements ##

# %%
morphology()

# %% [markdown]
# ## Siena vs Union Size Estimates ##

# %%
size()
# Out:
# /Users/rfinn/github/halphagui/testing/compare_union.py:151: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x[xvars[i]],y[yvars2[i]],'cs',label='GALFIT')

# %% [markdown]
# ## Siena vs Union Magnitudes ##

# %%
mag()
# Out:
# /Users/rfinn/github/halphagui/testing/compare_union.py:189: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x[xvars[i]],y[yvars2[i]],'cs',label='GALFIT')

# %% [markdown]
# ## Siena vs Union sSFRs: global, inner, outer ##

# %%
sfr()
# Out:
# /Users/rfinn/github/halphagui/testing/compare_union.py:103: RuntimeWarning: invalid value encountered in true_divide
#   else:
# /Users/rfinn/github/halphagui/testing/compare_union.py:103: RuntimeWarning: divide by zero encountered in log10
#   else:
# /Users/rfinn/github/halphagui/testing/compare_union.py:105: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(x[xvars[i]],np.log10(y[yvars2[i]]),'cs', label='GALFIT')
# /Users/rfinn/github/halphagui/testing/compare_union.py:108: RuntimeWarning: divide by zero encountered in log10
#   x1,x2 = plt.xlim()
# /Users/rfinn/github/halphagui/testing/compare_union.py:108: RuntimeWarning: invalid value encountered in log10
#   x1,x2 = plt.xlim()
# /Users/rfinn/github/halphagui/testing/compare_union.py:109: RuntimeWarning: divide by zero encountered in log10
#   xl = np.linspace(x1,x2,100)
# /Users/rfinn/github/halphagui/testing/compare_union.py:109: RuntimeWarning: invalid value encountered in log10
# ...
